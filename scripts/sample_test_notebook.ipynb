# %%
import pandas as pd
from joblib import Parallel, delayed
import warnings, json, ast, duckdb

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns',500)

# %%
df = pd.read_csv('../output/json_extracted_data.csv')

# %%
# Select only male player matches
df = df[df['info.gender'] == 'male'][['match_id','innings','info.outcome.winner','info.teams','info.venue']].head(2)

# %%
df
# Out:
#    match_id                                            innings  \
# 0         1  [{'team': 'Australia', 'overs': [{'over': 0, '...
# 1         2  [{'team': 'Australia', 'overs': [{'over': 0, '...
#
#   info.outcome.winner                 info.teams  \
# 0           Australia  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
#
#                                info.venue
# 0  Brisbane Cricket Ground, Woolloongabba
# 1                Melbourne Cricket Ground

# %%
df['innings'] = Parallel(n_jobs=-1)(delayed(ast.literal_eval)(x) for x in df['innings'])

# %%
test_df = df.copy()
test_df
# Out:
#    match_id                                            innings  \
# 0         1  [{'team': 'Australia', 'overs': [{'over': 0, '...
# 1         2  [{'team': 'Australia', 'overs': [{'over': 0, '...
#
#   info.outcome.winner                 info.teams  \
# 0           Australia  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
#
#                                info.venue
# 0  Brisbane Cricket Ground, Woolloongabba
# 1                Melbourne Cricket Ground

# %%
# pd.json_normalize(
#     test_df.explode('innings').to_dict(orient='records'),
#     record_path=['innings', 'overs'],
#     meta=['innings.team', 'info.venue'],
#     errors='ignore'
# )

# %%
test_df2 = test_df.explode('innings')
test_df2
# Out:
#    match_id                                            innings  \
# 0         1  {'team': 'Australia', 'overs': [{'over': 0, 'd...
# 0         1  {'team': 'Pakistan', 'overs': [{'over': 0, 'de...
# 1         2  {'team': 'Australia', 'overs': [{'over': 0, 'd...
# 1         2  {'team': 'Pakistan', 'overs': [{'over': 0, 'de...
#
#   info.outcome.winner                 info.teams  \
# 0           Australia  ['Australia', 'Pakistan']
# 0           Australia  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
#
#                                info.venue
# 0  Brisbane Cricket Ground, Woolloongabba
# 0  Brisbane Cricket Ground, Woolloongabba
# 1                Melbourne Cricket Ground
# 1                Melbourne Cricket Ground

# %%
# working logic

pd.json_normalize(
    test_df2.to_dict(orient='records'),
    record_path=['innings','overs','deliveries'],  # Adjust if deliveries are nested
    meta=['match_id','innings.team', 'info.outcome.winner', 'info.teams', 'info.venue'],
    errors='ignore'
) #[['match_id','innings.team','batter','bowler','runs.total','info.teams','info.venue']].head()
# Out:
#           batter         bowler   non_striker  runs.batter  runs.extras  \
# 0      DA Warner  Mohammad Amir       TM Head            0            0
# 1      DA Warner  Mohammad Amir       TM Head            0            0
# 2      DA Warner  Mohammad Amir       TM Head            0            0
# 3      DA Warner  Mohammad Amir       TM Head            0            0
# 4      DA Warner  Mohammad Amir       TM Head            0            1
# ...          ...            ...           ...          ...          ...
# 1156  Umar Akmal        TM Head  Shoaib Malik            0            0
# 1157  Umar Akmal        TM Head  Shoaib Malik            4            0
# 1158  Umar Akmal        TM Head  Shoaib Malik            0            0
# 1159  Umar Akmal        TM Head  Shoaib Malik            4            0
# 1160  Umar Akmal        TM Head  Shoaib Malik            0            1
#
#       runs.total  extras.wides wickets runs.non_boundary review.by  \
# 0              0           NaN     NaN               NaN       NaN
# 1              0           NaN     NaN               NaN       NaN
# 2              0           NaN     NaN               NaN       NaN
# 3              0           NaN     NaN               NaN       NaN
# 4              1           1.0     NaN               NaN       NaN
# ...          ...           ...     ...               ...       ...
# 1156           0           NaN     NaN               NaN       NaN
# 1157           4           NaN     NaN               NaN       NaN
# 1158           0           NaN     NaN               NaN       NaN
# 1159           4           NaN     NaN               NaN       NaN
# 1160           1           1.0     NaN               NaN       NaN
#
#      review.umpire review.batter review.decision  extras.legbyes  \
# 0              NaN           NaN             NaN             NaN
# 1              NaN           NaN             NaN             NaN
# 2              NaN           NaN             NaN             NaN
# 3              NaN           NaN             NaN             NaN
# 4              NaN           NaN             NaN             NaN
# ...            ...           ...             ...             ...
# 1156           NaN           NaN             NaN             NaN
# 1157           NaN           NaN             NaN             NaN
# 1158           NaN           NaN             NaN             NaN
# 1159           NaN           NaN             NaN             NaN
# 1160           NaN           NaN             NaN             NaN
#
#       extras.noballs  extras.byes replacements.role match_id innings.team  \
# 0                NaN          NaN               NaN        1          NaN
# 1                NaN          NaN               NaN        1          NaN
# 2                NaN          NaN               NaN        1          NaN
# 3                NaN          NaN               NaN        1          NaN
# 4                NaN          NaN               NaN        1          NaN
# ...              ...          ...               ...      ...          ...
# 1156             NaN          NaN               NaN        2          NaN
# 1157             NaN          NaN               NaN        2          NaN
# 1158             NaN          NaN               NaN        2          NaN
# 1159             NaN          NaN               NaN        2          NaN
# 1160             NaN          NaN               NaN        2          NaN
#
#      info.outcome.winner                 info.teams  \
# 0              Australia  ['Australia', 'Pakistan']
# 1              Australia  ['Australia', 'Pakistan']
# 2              Australia  ['Australia', 'Pakistan']
# 3              Australia  ['Australia', 'Pakistan']
# 4              Australia  ['Australia', 'Pakistan']
# ...                  ...                        ...
# 1156            Pakistan  ['Australia', 'Pakistan']
# 1157            Pakistan  ['Australia', 'Pakistan']
# 1158            Pakistan  ['Australia', 'Pakistan']
# 1159            Pakistan  ['Australia', 'Pakistan']
# 1160            Pakistan  ['Australia', 'Pakistan']
#
#                                   info.venue
# 0     Brisbane Cricket Ground, Woolloongabba
# 1     Brisbane Cricket Ground, Woolloongabba
# 2     Brisbane Cricket Ground, Woolloongabba
# 3     Brisbane Cricket Ground, Woolloongabba
# 4     Brisbane Cricket Ground, Woolloongabba
# ...                                      ...
# 1156                Melbourne Cricket Ground
# 1157                Melbourne Cricket Ground
# 1158                Melbourne Cricket Ground
# 1159                Melbourne Cricket Ground
# 1160                Melbourne Cricket Ground
#
# [1161 rows x 22 columns]

# %%
###################################################################################

# %%
test_df
# Out:
#    match_id                                            innings  \
# 0         1  [{'team': 'Australia', 'overs': [{'over': 0, '...
# 1         2  [{'team': 'Australia', 'overs': [{'over': 0, '...
#
#   info.outcome.winner                 info.teams  \
# 0           Australia  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
#
#                                info.venue
# 0  Brisbane Cricket Ground, Woolloongabba
# 1                Melbourne Cricket Ground

# %%
# Explode the 'innings' column
df_exploded = test_df.explode('innings')

# Extract 'team' separately
df_exploded['innings_team'] = df_exploded['innings'].apply(lambda x: x.get('team') if isinstance(x, dict) else None)

# Normalize the rest of the data
normalized_df = pd.json_normalize(
    df_exploded.to_dict(orient='records'),
    record_path=['innings', 'overs', 'deliveries'],
    meta=['match_id', 'innings_team', 'info.outcome.winner', 'info.teams', 'info.venue'],
    errors='ignore'
)

# Display the result
normalized_df.head()
# Out:
#       batter         bowler non_striker  runs.batter  runs.extras  runs.total  \
# 0  DA Warner  Mohammad Amir     TM Head            0            0           0
# 1  DA Warner  Mohammad Amir     TM Head            0            0           0
# 2  DA Warner  Mohammad Amir     TM Head            0            0           0
# 3  DA Warner  Mohammad Amir     TM Head            0            0           0
# 4  DA Warner  Mohammad Amir     TM Head            0            1           1
#
#    extras.wides wickets runs.non_boundary review.by review.umpire  \
# 0           NaN     NaN               NaN       NaN           NaN
# 1           NaN     NaN               NaN       NaN           NaN
# 2           NaN     NaN               NaN       NaN           NaN
# 3           NaN     NaN               NaN       NaN           NaN
# 4           1.0     NaN               NaN       NaN           NaN
#
#   review.batter review.decision  extras.legbyes  extras.noballs  extras.byes  \
# 0           NaN             NaN             NaN             NaN          NaN
# 1           NaN             NaN             NaN             NaN          NaN
# 2           NaN             NaN             NaN             NaN          NaN
# 3           NaN             NaN             NaN             NaN          NaN
# 4           NaN             NaN             NaN             NaN          NaN
#
#   replacements.role match_id innings_team info.outcome.winner  \
# 0               NaN        1    Australia           Australia
# 1               NaN        1    Australia           Australia
# 2               NaN        1    Australia           Australia
# 3               NaN        1    Australia           Australia
# 4               NaN        1    Australia           Australia
#
#                   info.teams                              info.venue
# 0  ['Australia', 'Pakistan']  Brisbane Cricket Ground, Woolloongabba
# 1  ['Australia', 'Pakistan']  Brisbane Cricket Ground, Woolloongabba
# 2  ['Australia', 'Pakistan']  Brisbane Cricket Ground, Woolloongabba
# 3  ['Australia', 'Pakistan']  Brisbane Cricket Ground, Woolloongabba
# 4  ['Australia', 'Pakistan']  Brisbane Cricket Ground, Woolloongabba

# %%
abc = test_df.explode('innings')
abc['innings_team'] = df_exploded['innings'].apply(lambda x: x.get('team') if isinstance(x, dict) else None)
abc
# Out:
#    match_id                                            innings  \
# 0         1  {'team': 'Australia', 'overs': [{'over': 0, 'd...
# 0         1  {'team': 'Pakistan', 'overs': [{'over': 0, 'de...
# 1         2  {'team': 'Australia', 'overs': [{'over': 0, 'd...
# 1         2  {'team': 'Pakistan', 'overs': [{'over': 0, 'de...
#
#   info.outcome.winner                 info.teams  \
# 0           Australia  ['Australia', 'Pakistan']
# 0           Australia  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
# 1            Pakistan  ['Australia', 'Pakistan']
#
#                                info.venue innings_team
# 0  Brisbane Cricket Ground, Woolloongabba    Australia
# 0  Brisbane Cricket Ground, Woolloongabba     Pakistan
# 1                Melbourne Cricket Ground    Australia
# 1                Melbourne Cricket Ground     Pakistan

# %%
#########################################################################################################

# %%
import pandas as pd

# %%
df = pd.read_csv('../output/deliveries_final.csv')

# %%
df.venue.unique()
# Out:
# array(['Brisbane Cricket Ground, Woolloongabba',
#        'Melbourne Cricket Ground',
#        'Western Australia Cricket Association Ground',
#        'Sydney Cricket Ground', 'Adelaide Oval', 'Manuka Oval',
#        'Hagley Oval', 'Saxton Oval', 'Eden Park', 'Seddon Park',
#        'Westpac Stadium', 'Kennington Oval', 'Edgbaston',
#        'Sophia Gardens', 'Sir Vivian Richards Stadium, North Sound',
#        'Kensington Oval, Bridgetown', 'Shere Bangla National Stadium',
#        'Zahur Ahmed Chowdhury Stadium', 'Feroz Shah Kotla',
#        'Punjab Cricket Association Stadium, Mohali',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Headingley', 'The Rose Bowl', "Lord's", 'Old Trafford',
#        'County Ground', 'Clontarf Cricket Club Ground',
#        'Maharashtra Cricket Association Stadium', 'Barabati Stadium',
#        'Eden Gardens', 'Sharjah Cricket Stadium', 'Sheikh Zayed Stadium',
#        'Harare Sports Club', 'Queens Sports Club', 'Providence Stadium',
#        'Rangiri Dambulla International Stadium',
#        'Sinhalese Sports Club Ground', "Queen's Park Oval, Port of Spain",
#        'Sabina Park, Kingston', 'Pallekele International Cricket Stadium',
#        'R.Premadasa Stadium, Khettarama', 'Bay Oval', 'University Oval',
#        'MA Chidambaram Stadium, Chepauk',
#        'Vidarbha Cricket Association Stadium, Jamtha', 'Trent Bridge',
#        'Riverside Ground', 'Wankhede Stadium', 'Green Park',
#        'Dubai International Cricket Stadium', 'Kingsmead',
#        'SuperSport Park', 'Newlands', 'The Wanderers Stadium',
#        "St George's Park", 'Shere Bangla National Stadium, Mirpur',
#        'Bellerive Oval', 'Warner Park, Basseterre',
#        'Sylhet International Cricket Stadium', 'McLean Park',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'The Village, Malahide', 'National Stadium',
#        'Mahinda Rajapaksa International Cricket Stadium, Sooriyawewa',
#        'SuperSport Park, Centurion', 'R Premadasa Stadium, Colombo',
#        'Kensington Oval, Bridgetown, Barbados', 'Newlands, Cape Town',
#        'Narendra Modi Stadium, Ahmedabad', 'Gaddafi Stadium, Lahore',
#        'Multan Cricket Stadium', 'National Stadium, Karachi',
#        'Rawalpindi Cricket Stadium', 'Eden Gardens, Kolkata',
#        'Wankhede Stadium, Mumbai', 'Arnos Vale Ground, Kingstown',
#        'Nehru Stadium', 'Gaddafi Stadium', 'New Wanderers Stadium',
#        'R Premadasa Stadium', 'Beausejour Stadium, Gros Islet',
#        "National Cricket Stadium, St George's", 'Sawai Mansingh Stadium',
#        'Sardar Patel Stadium, Motera', 'Kinrara Academy Oval',
#        'Civil Service Cricket Club, Stormont', 'M Chinnaswamy Stadium',
#        'Willowmoore Park', 'Sharjah Cricket Association Stadium'],
#       dtype=object)
